# %% [markdown]
# ## Profiling
#
# Analisando a qualidade dos dados

# %%
import pandas_profiling
import pandas as pd

# %%
df_gestante = pd.read_csv('../../data/SINAN/SifGestante_2007_2017_Long.csv', sep=';')

df_gestante.info()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195218 entries, 0 to 195217
# Data columns (total 37 columns):
# ctrlsifgn     195218 non-null int64
# id_agravo     195218 non-null object
# dt_notific    195218 non-null object
# nu_ano        195218 non-null int64
# ANODIAG       195218 non-null int64
# sg_uf_not     195218 non-null int64
# id_municip    195218 non-null int64
# id_regiona    195218 non-null object
# id_unidade    195218 non-null object
# dt_diag       195218 non-null object
# sem_diag      195218 non-null object
# dt_nasc       195218 non-null object
# nu_idade_n    195218 non-null int64
# nu_idade      195218 non-null int64
# FXETARIA      195218 non-null int64
# cs_sexo       195218 non-null object
# ...

# %%
pd.options.display.max_columns = None

df_gestante.head()
# Out:
#    ctrlsifgn id_agravo  dt_notific  nu_ano  ANODIAG  sg_uf_not  id_municip  \
# 0        469      O981   9/10/2013    2013     2005         42      421190
# 1        470      O981   1/25/2013    2013     2005         33      330455
# 2        471      O981   1/22/2010    2010     2005         35      355030
# 3        472      O981   7/10/2012    2012     2005         29      290270
# 4        473      O981  11/27/2007    2007     2005         24      240810
#
#   id_regiona id_unidade    dt_diag sem_diag     dt_nasc  nu_idade_n  nu_idade  \
# 0       1476    5969018   1/1/2005             5/4/1981        4023        23
# 1               2273373  1/11/2005            7/12/1977        4027        27
# 2       1331    2789167  3/24/2005            9/28/1981        4023        23
# 3       1403    5496284   4/4/2005            5/24/1982        4022        22
# 4       1416    2409208  4/23/2005           10/23/1983        4021        21
#
# ...

# %% [markdown]
# ## Usando pandas_profiling
#
# Usando a biblioteca para acelerar o processo de análise da qualidade dos dados

# %%
pandas_profiling.ProfileReport(df_gestante)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# | Coluna            | Descição                                                            | Valores                           | OBS                                                | Tratamento                                         |
# | ----------------- | ------------------------------------------------------------------- | --------------------------------- | -------------------------------------------------- | -------------------------------------------------- |
# | ANODIAG           | Ano do diagnóstico                                                  | -                                 | Correlação forte com nu_ano (0.99)                 | Retirar                                            |
# | CLASSCLI          | Classificação clínica                                               | Entre 1,4+ 9                      | -                                                  | -                                                  |
# | ESQ_TRAT          | Esquema de tratamento prescito à gestante                           | Entre 1,5 +9                      | -                                                  | -                                                  |
# | FXETARIA          | Faixa etária da gestante                                            | -                                 | Correlação forte com nu_idade(0.91)                | Retirar                                            |
# | UFRES             | UF de residência                                                    | 28 valores                        | -                                                  | -                                                  |
# | cs_escolaridade_n | Classificação do nível de escolaridade                              | Entre 1,8+99+10                   | -                                                  | -                                                  |
# | cs_gestant        | Classificação do trimestre da gestação                              | Entre1,4+9                        | -                                                  | -                                                  |
# | cs_raca           | Classificação da raça                                               | Entre 1,5+ 9                      | -                                                  | -                                                  |
# | cs_sexo           | Classificação do sexo                                               | F                                 | Presença de ' ', respostas constantes              | Retirar                                            |
# | cs_zona           | Zona de residência                                                  | Entre 1,3+9                       | -                                                  | -                                                  |
# | ctrlsifgn         | Alguma variável de controla, próximo a um id da fich, provavelmente | 195218 valores                    | Pouco relevante                                    | Retirar                                            |
# | dsmotivo          | ?                                                                   | 154 valores                       | Presença de ' ' (99.9%)                            | Retirar                                            |
# | dstitulo1         | Titulo                                                              | 771 valores                       | Presença de ' '(11.4%)                             | -                                                  |
# | dt_diag           | Data do diagnóstico                                                 | 3974 valores                      | mes/dia/ano                                        | Converter para tipo data, checar todos os formatos |
# | dt_nasc           | Data de nascimento                                                  | 13107 valores                     | mes/dia/ano, presença de ' ' 2.4%                  | Retirar                                            |
# | dt_notific        | Data da notificação                                                 | 39807                             | mes/dia/ano                                        | -                                                  |
# | id_agravo         | Agravo                                                              | O981                              | Constante                                          | Retirar                                            |
# | id_mn_resi        | Município de residência                                             | 4634 valores                      | provavelmente tem ' '                              | -                                                  |
# | id_municip        | Município                                                           | -                                 | Correlação forte com sg_uf_not 0.99%               | Retirar                                            |
# | id_ocupa_n        | Ocupação                                                            | 651 valores                       | Presença de ' ' (35.5%)                            | Retirar                                            |
# | id_pais           | País                                                                | 1, 126, 138, 68, 199, 191, 137, 7 | -                                                  | -                                                  |
# | id_regiona        | Região (de saúde?)                                                  | 354 valores                       | Presença de ' ' (16.9%')                           | Retirar                                            |
# | id_unidade        | Unidade de saúde                                                    | 35074 valores                     | -                                                  | Possível retirar                                   |
# | nu_ano            | Ano da notificação?                                                 | -                                 | Correlação forte com ctrlsifgn(0.95)               | Retirar                                            |
# | nu_idade          | Idade                                                               | 56 valores                        | Muitos valores baixos (0-9) e muito altos (60-127) | Retirar                                            |
# | nu_idade_n        | Idade categorizada                                                  | 92 valores                        | Muitos valores baixos e inconsistentes             | Retirar                                            |
# | pre_munire        | Município de realização do pré-natal                                | 4689 valores                      | Presença de ' '(8%)                                | Retirar                                            |
# | pre_sispre        | Código do sispre                                                    | 69721 valores                     | Presença de ' '(35.5%)                             | Retirar                                            |
# | pre_ufrel         | UF de realização do pré-natal                                       | 28 valores                        | Presença de ' ' 6%                                 | Retirar                                            |
# | pre_unipre        | Unidade de realização do pré-natal                                  | 19204 valores                     | Presença de ' '41%                                 | Retirar                                            |
# | sem_diag_         | -                                                                   | ' '                               | Constante                                          | Retirar                                            |
# | sg_uf_not         | UF de notificação                                                   | 28 valores                        | -                                                  | -                                                  |
# | tpconfirma        | -                                                                   | Entre 1,3 +9                      | -                                                  | -                                                  |
# | tpesqupar         | Tipo de esquema de tratamento do parceiro                           | -                                 | Correlação forte com tratparc 0.94                 | Retirar                                            |
# | tpmotparc         | Motivo para não tratamento do parceiro                              | Entre 1,6+9                       | -                                                  | -                                                  |
# | tptest1           | Teste                                                               | Entre 1,3 +9                      | -                                                  | -                                                  |
# | tratparc          | Parceiro tratado                                                    | 1, 2, 9                           | -                                                  | -                                                  |
